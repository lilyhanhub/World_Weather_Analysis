# %%
# Import the dependencies:
from citipy import citipy 
import pandas as pd
import numpy as np
import requests

# %%
# Create a set of 2,000 random latitude and longitude combinations 
lats = np.random.uniform(low=-90.000,high=90.000, size =2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size =2000)
lat_lngs = zip(lats, lngs)

# Add the latitutdes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 755

# %%
# Import the API key.
from config import weather_api_key 

# Import the datetime module from the datetime library.
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data
city_data = []
# Print the begining of the logging
print("Beginning Data Retrieval ")
print("------------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i%50 ==0 and i >=50):
        set_count += 1
        record_count += 1
        time.sleep(60)
    
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the rocord count
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | port elizabeth
# Processing Record 4 of Set 1 | komsomolskiy
# Processing Record 5 of Set 1 | bathurst
# Processing Record 6 of Set 1 | lebu
# Processing Record 7 of Set 1 | roald
# Processing Record 8 of Set 1 | riyadh
# Processing Record 9 of Set 1 | codrington
# Processing Record 10 of Set 1 | sangar
# Processing Record 11 of Set 1 | new norfolk
# Processing Record 12 of Set 1 | baruun-urt
# Processing Record 13 of Set 1 | pascagoula
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | moerai
# Processing Record 16 of Set 1 | east london
# Processing Record 17 of Set 1 | namatanai
# Processing Record 18 of Set 1 | bambanglipuro
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | tiksi
# Processing Record 21 of Set 1 | oktyabrskoye
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | payo
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | lagoa
# Processing Record 26 of Set 1 | vrangel
# Processing Record 27 of Set 1 | kahului
# Processing Record 28 of Set 1 | moissala
# Processing Record 29 of Set 1 | ancud
# Processing Record 30 of Set 1 | sinnamary
# Processing Record 31 of Set 1 | faanui
# Processing Record 32 of Set 1 | bathsheba
# Processing Record 33 of Set 1 | magistralnyy
# Processing Record 34 of Set 1 | grand gaube
# Processing Record 35 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | nelson bay
# Processing Record 38 of Set 1 | avera
# Processing Record 39 of Set 1 | victoria
# Processing Record 40 of Set 1 | querecotillo
# Processing Record 41 of Set 1 | hilo
# Processing Record 42 of Set 1 | nikolskoye
# Processing Record 43 of Set 1 | panama city
# Processing Record 44 of Set 1 | ushuaia
# Processing Record 45 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 1 | phillipsburg
# Processing Record 47 of Set 1 | talnakh
# Processing Record 48 of Set 1 | katsuura
# Processing Record 49 of Set 1 | atuona
# Processing Record 50 of Set 1 | kununurra
# Processing Record 52 of Set 2 | san diego de los banos
# Processing Record 53 of Set 2 | busselton
# Processing Record 54 of Set 2 | beroroha
# Processing Record 55 of Set 2 | vaini
# Processing Record 56 of Set 2 | lavrentiya
# Processing Record 57 of Set 2 | hurghada
# Processing Record 58 of Set 2 | odweyne
# Processing Record 59 of Set 2 | luderitz
# Processing Record 60 of Set 2 | guerrero negro
# Processing Record 61 of Set 2 | ponta do sol
# Processing Record 62 of Set 2 | toropets
# Processing Record 63 of Set 2 | sitka
# Processing Record 64 of Set 2 | kavaratti
# Processing Record 65 of Set 2 | qaanaaq
# Processing Record 66 of Set 2 | esperance
# Processing Record 67 of Set 2 | airai
# Processing Record 68 of Set 2 | chegem
# Processing Record 69 of Set 2 | chachapoyas
# Processing Record 70 of Set 2 | saskylakh
# Processing Record 71 of Set 2 | lompoc
# Processing Record 72 of Set 2 | milan
# Processing Record 73 of Set 2 | port alfred
# Processing Record 74 of Set 2 | castro
# Processing Record 75 of Set 2 | dunedin
# Processing Record 76 of Set 2 | domoni
# Processing Record 77 of Set 2 | nebolchi
# Processing Record 78 of Set 2 | bonthe
# Processing Record 79 of Set 2 | albany
# Processing Record 80 of Set 2 | vanimo
# Processing Record 81 of Set 2 | potgietersrus
# City not found. Skipping...
# Processing Record 82 of Set 2 | clyde river
# Processing Record 83 of Set 2 | avarua
# Processing Record 84 of Set 2 | dingle
# Processing Record 85 of Set 2 | karamea
# City not found. Skipping...
# Processing Record 86 of Set 2 | kruisfontein
# Processing Record 87 of Set 2 | san patricio
# Processing Record 88 of Set 2 | dawlatabad
# Processing Record 89 of Set 2 | kota kinabalu
# Processing Record 90 of Set 2 | thinadhoo
# Processing Record 91 of Set 2 | maykor
# Processing Record 92 of Set 2 | bengkulu
# Processing Record 93 of Set 2 | dikson
# Processing Record 94 of Set 2 | yulara
# Processing Record 95 of Set 2 | menongue
# Processing Record 96 of Set 2 | atar
# Processing Record 97 of Set 2 | mataura
# Processing Record 98 of Set 2 | mazamari
# Processing Record 99 of Set 2 | kailua
# Processing Record 100 of Set 2 | kitimat
# Processing Record 101 of Set 2 | litoral del san juan
# City not found. Skipping...
# Processing Record 103 of Set 3 | tiznit
# Processing Record 104 of Set 3 | arraial do cabo
# Processing Record 105 of Set 3 | santiago del estero
# Processing Record 106 of Set 3 | lasa
# Processing Record 107 of Set 3 | saint anthony
# Processing Record 108 of Set 3 | oranjemund
# Processing Record 109 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 110 of Set 3 | pisco
# Processing Record 111 of Set 3 | sarangani
# Processing Record 112 of Set 3 | butaritari
# Processing Record 113 of Set 3 | panaba
# Processing Record 114 of Set 3 | elko
# Processing Record 115 of Set 3 | bredasdorp
# Processing Record 116 of Set 3 | cidreira
# Processing Record 117 of Set 3 | bluff
# Processing Record 118 of Set 3 | kaeo
# Processing Record 119 of Set 3 | hofn
# Processing Record 120 of Set 3 | tazovskiy
# Processing Record 121 of Set 3 | mar del plata
# Processing Record 122 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 123 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 124 of Set 3 | inhambane
# Processing Record 125 of Set 3 | urumqi
# Processing Record 126 of Set 3 | port hardy
# Processing Record 127 of Set 3 | umm ruwabah
# City not found. Skipping...
# Processing Record 128 of Set 3 | khuzhir
# Processing Record 129 of Set 3 | ampanihy
# Processing Record 130 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 131 of Set 3 | kapaa
# Processing Record 132 of Set 3 | san jose
# Processing Record 133 of Set 3 | tasiilaq
# Processing Record 134 of Set 3 | husavik
# Processing Record 135 of Set 3 | ribeira grande
# Processing Record 136 of Set 3 | vestbygda
# City not found. Skipping...
# Processing Record 137 of Set 3 | buraydah
# Processing Record 138 of Set 3 | cockburn harbour
# City not found. Skipping...
# Processing Record 139 of Set 3 | tabou
# Processing Record 140 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 141 of Set 3 | nakusp
# Processing Record 142 of Set 3 | upernavik
# Processing Record 143 of Set 3 | marawi
# Processing Record 144 of Set 3 | kodiak
# Processing Record 145 of Set 3 | lorengau
# Processing Record 146 of Set 3 | tsabong
# Processing Record 147 of Set 3 | thompson
# Processing Record 148 of Set 3 | hobart
# Processing Record 149 of Set 3 | klaksvik
# Processing Record 150 of Set 3 | buchanan
# Processing Record 151 of Set 3 | yining
# Processing Record 152 of Set 3 | ponta delgada
# Processing Record 154 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 155 of Set 4 | abasha
# Processing Record 156 of Set 4 | strezhevoy
# Processing Record 157 of Set 4 | vilcun
# Processing Record 158 of Set 4 | domodossola
# Processing Record 159 of Set 4 | sao joao da barra
# Processing Record 160 of Set 4 | ilulissat
# Processing Record 161 of Set 4 | severo-kurilsk
# Processing Record 162 of Set 4 | poum
# Processing Record 163 of Set 4 | geraldton
# Processing Record 164 of Set 4 | saint-joseph
# Processing Record 165 of Set 4 | mahebourg
# Processing Record 166 of Set 4 | jalu
# Processing Record 167 of Set 4 | barrow
# Processing Record 168 of Set 4 | nakatsugawa
# Processing Record 169 of Set 4 | malpe
# Processing Record 170 of Set 4 | leningradskiy
# Processing Record 171 of Set 4 | cape coral
# Processing Record 172 of Set 4 | ca mau
# Processing Record 173 of Set 4 | houston
# Processing Record 174 of Set 4 | raglan
# Processing Record 175 of Set 4 | acapulco
# Processing Record 176 of Set 4 | sembe
# Processing Record 177 of Set 4 | cockburn town
# Processing Record 178 of Set 4 | harnai
# Processing Record 179 of Set 4 | khatanga
# Processing Record 180 of Set 4 | hasaki
# Processing Record 181 of Set 4 | deputatskiy
# Processing Record 182 of Set 4 | chadiza
# Processing Record 183 of Set 4 | nioro
# Processing Record 184 of Set 4 | sao filipe
# Processing Record 185 of Set 4 | te anau
# Processing Record 186 of Set 4 | sibolga
# Processing Record 187 of Set 4 | kawalu
# Processing Record 188 of Set 4 | quatre cocos
# Processing Record 189 of Set 4 | jamestown
# Processing Record 190 of Set 4 | shingu
# Processing Record 191 of Set 4 | bosaso
# Processing Record 192 of Set 4 | mbandaka
# Processing Record 193 of Set 4 | hamada
# Processing Record 194 of Set 4 | taoudenni
# Processing Record 195 of Set 4 | ayan
# Processing Record 196 of Set 4 | douglas
# Processing Record 197 of Set 4 | iskateley
# Processing Record 198 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 199 of Set 4 | torbay
# Processing Record 200 of Set 4 | kaolinovo
# Processing Record 201 of Set 4 | rundu
# Processing Record 202 of Set 4 | fortuna
# Processing Record 203 of Set 4 | hibbing
# Processing Record 205 of Set 5 | rosarito
# Processing Record 206 of Set 5 | savannakhet
# Processing Record 207 of Set 5 | souillac
# Processing Record 208 of Set 5 | dongli
# Processing Record 209 of Set 5 | tsiroanomandidy
# Processing Record 210 of Set 5 | mitchell
# Processing Record 211 of Set 5 | vostok
# Processing Record 212 of Set 5 | aksarka
# Processing Record 213 of Set 5 | cabo san lucas
# Processing Record 214 of Set 5 | salalah
# Processing Record 215 of Set 5 | adrar
# Processing Record 216 of Set 5 | boulder
# Processing Record 217 of Set 5 | sept-iles
# Processing Record 218 of Set 5 | basco
# Processing Record 219 of Set 5 | rawson
# Processing Record 220 of Set 5 | anloga
# Processing Record 221 of Set 5 | uvat
# Processing Record 222 of Set 5 | chuy
# Processing Record 223 of Set 5 | churapcha
# Processing Record 224 of Set 5 | miyako
# Processing Record 225 of Set 5 | selizharovo
# Processing Record 226 of Set 5 | namibe
# Processing Record 227 of Set 5 | aklavik
# Processing Record 228 of Set 5 | hithadhoo
# Processing Record 229 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 230 of Set 5 | villarrica
# Processing Record 231 of Set 5 | dera bugti
# Processing Record 232 of Set 5 | bulawayo
# Processing Record 233 of Set 5 | los llanos de aridane
# Processing Record 234 of Set 5 | samarai
# Processing Record 235 of Set 5 | ozinki
# Processing Record 236 of Set 5 | dwarka
# Processing Record 237 of Set 5 | warren
# Processing Record 238 of Set 5 | soyo
# Processing Record 239 of Set 5 | saint george
# Processing Record 240 of Set 5 | georgetown
# Processing Record 241 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 242 of Set 5 | carutapera
# Processing Record 243 of Set 5 | laredo
# Processing Record 244 of Set 5 | nouadhibou
# Processing Record 245 of Set 5 | nerchinskiy zavod
# Processing Record 246 of Set 5 | gzhatsk
# City not found. Skipping...
# Processing Record 247 of Set 5 | tanakpur
# Processing Record 248 of Set 5 | san javier
# Processing Record 249 of Set 5 | caucaia
# Processing Record 250 of Set 5 | zhezkazgan
# Processing Record 251 of Set 5 | srandakan
# Processing Record 252 of Set 5 | palu
# Processing Record 253 of Set 5 | niksar
# Processing Record 254 of Set 5 | funadhoo
# Processing Record 256 of Set 6 | tigil
# Processing Record 257 of Set 6 | lodwar
# Processing Record 258 of Set 6 | mobaye
# Processing Record 259 of Set 6 | jacareacanga
# Processing Record 260 of Set 6 | auki
# Processing Record 261 of Set 6 | takoradi
# Processing Record 262 of Set 6 | camacha
# Processing Record 263 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 264 of Set 6 | abomey
# Processing Record 265 of Set 6 | zhumadian
# Processing Record 266 of Set 6 | pierre
# Processing Record 267 of Set 6 | maragogi
# Processing Record 268 of Set 6 | boa vista
# Processing Record 269 of Set 6 | ailigandi
# Processing Record 270 of Set 6 | kaitangata
# Processing Record 271 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 272 of Set 6 | yeppoon
# Processing Record 273 of Set 6 | narsaq
# Processing Record 274 of Set 6 | ordynskoye
# Processing Record 275 of Set 6 | lambarene
# Processing Record 276 of Set 6 | durban
# Processing Record 277 of Set 6 | kleinbettingen
# Processing Record 278 of Set 6 | suez
# Processing Record 279 of Set 6 | orotukan
# Processing Record 280 of Set 6 | goias
# Processing Record 281 of Set 6 | stornoway
# Processing Record 282 of Set 6 | nemuro
# Processing Record 283 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 284 of Set 6 | kupang
# Processing Record 285 of Set 6 | novikovo
# Processing Record 286 of Set 6 | westport
# Processing Record 287 of Set 6 | searcy
# Processing Record 288 of Set 6 | nhulunbuy
# Processing Record 289 of Set 6 | aranos
# Processing Record 290 of Set 6 | skagastrond
# City not found. Skipping...
# Processing Record 291 of Set 6 | fort nelson
# Processing Record 292 of Set 6 | lanzhou
# Processing Record 293 of Set 6 | toamasina
# Processing Record 294 of Set 6 | ouro preto do oeste
# Processing Record 295 of Set 6 | dinsor
# City not found. Skipping...
# Processing Record 296 of Set 6 | sabancuy
# Processing Record 297 of Set 6 | sorong
# Processing Record 298 of Set 6 | bani
# Processing Record 299 of Set 6 | hirara
# Processing Record 300 of Set 6 | nanortalik
# Processing Record 301 of Set 6 | coquimbo
# Processing Record 302 of Set 6 | anzio
# Processing Record 303 of Set 6 | owando
# Processing Record 304 of Set 6 | olafsvik
# Processing Record 305 of Set 6 | zwedru
# Processing Record 307 of Set 7 | faya
# Processing Record 308 of Set 7 | saint peter
# Processing Record 309 of Set 7 | huambo
# Processing Record 310 of Set 7 | makakilo city
# Processing Record 311 of Set 7 | bandarbeyla
# Processing Record 312 of Set 7 | buala
# Processing Record 313 of Set 7 | jucas
# Processing Record 314 of Set 7 | yantal
# Processing Record 315 of Set 7 | toftir
# City not found. Skipping...
# Processing Record 316 of Set 7 | pevek
# Processing Record 317 of Set 7 | margate
# Processing Record 318 of Set 7 | mazabuka
# Processing Record 319 of Set 7 | xam nua
# Processing Record 320 of Set 7 | mount isa
# Processing Record 321 of Set 7 | mentok
# City not found. Skipping...
# Processing Record 322 of Set 7 | cherskiy
# Processing Record 323 of Set 7 | pangody
# Processing Record 324 of Set 7 | hambantota
# Processing Record 325 of Set 7 | anadyr
# Processing Record 326 of Set 7 | kyshtovka
# Processing Record 327 of Set 7 | neryungri
# Processing Record 328 of Set 7 | muriwai beach
# Processing Record 329 of Set 7 | tuatapere
# Processing Record 330 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 331 of Set 7 | el alto
# Processing Record 332 of Set 7 | reefton
# City not found. Skipping...
# Processing Record 333 of Set 7 | teguldet
# Processing Record 334 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 335 of Set 7 | sakassou
# Processing Record 336 of Set 7 | harper
# Processing Record 337 of Set 7 | kholm-zhirkovskiy
# Processing Record 338 of Set 7 | thaton
# Processing Record 339 of Set 7 | bowen
# Processing Record 340 of Set 7 | khandyga
# Processing Record 341 of Set 7 | nome
# Processing Record 342 of Set 7 | havelock
# Processing Record 343 of Set 7 | belaya gora
# Processing Record 344 of Set 7 | mana
# Processing Record 345 of Set 7 | dzerzhinskoye
# Processing Record 346 of Set 7 | qui nhon
# Processing Record 347 of Set 7 | halifax
# Processing Record 348 of Set 7 | umm lajj
# Processing Record 349 of Set 7 | bambous virieux
# Processing Record 350 of Set 7 | gwanda
# Processing Record 351 of Set 7 | sabla
# Processing Record 352 of Set 7 | ocos
# Processing Record 353 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 354 of Set 7 | ambon
# Processing Record 355 of Set 7 | trincomalee
# Processing Record 356 of Set 7 | saint-philippe
# Processing Record 358 of Set 8 | grand forks
# Processing Record 359 of Set 8 | fairbanks
# Processing Record 360 of Set 8 | azimur
# City not found. Skipping...
# Processing Record 361 of Set 8 | nantong
# Processing Record 362 of Set 8 | labuhan
# Processing Record 363 of Set 8 | sur
# Processing Record 364 of Set 8 | raduzhnyy
# Processing Record 365 of Set 8 | catamarca
# Processing Record 366 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 367 of Set 8 | koungou
# Processing Record 368 of Set 8 | katherine
# Processing Record 369 of Set 8 | hovd
# Processing Record 370 of Set 8 | mackay
# Processing Record 371 of Set 8 | lithgow
# Processing Record 372 of Set 8 | omsukchan
# Processing Record 373 of Set 8 | vinukonda
# Processing Record 374 of Set 8 | neiafu
# Processing Record 375 of Set 8 | ormara
# Processing Record 376 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 377 of Set 8 | muros
# Processing Record 378 of Set 8 | santa cruz cabralia
# Processing Record 379 of Set 8 | kutum
# Processing Record 380 of Set 8 | paragominas
# Processing Record 381 of Set 8 | katy
# Processing Record 382 of Set 8 | wageningen
# Processing Record 383 of Set 8 | sao miguel do araguaia
# Processing Record 384 of Set 8 | richards bay
# Processing Record 385 of Set 8 | kavieng
# Processing Record 386 of Set 8 | belyy yar
# Processing Record 387 of Set 8 | saldanha
# Processing Record 388 of Set 8 | waipawa
# Processing Record 389 of Set 8 | ugoofaaru
# Processing Record 390 of Set 8 | tabukiniberu
# City not found. Skipping...
# Processing Record 391 of Set 8 | gondanglegi
# Processing Record 392 of Set 8 | iralaya
# Processing Record 393 of Set 8 | byron bay
# Processing Record 394 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 395 of Set 8 | goderich
# Processing Record 396 of Set 8 | provideniya
# Processing Record 397 of Set 8 | tuktoyaktuk
# Processing Record 398 of Set 8 | matara
# Processing Record 399 of Set 8 | zaoyang
# Processing Record 400 of Set 8 | monte alegre
# Processing Record 401 of Set 8 | vaitape
# Processing Record 402 of Set 8 | san cristobal
# Processing Record 403 of Set 8 | tokmak
# Processing Record 404 of Set 8 | meulaboh
# Processing Record 405 of Set 8 | pringsewu
# Processing Record 406 of Set 8 | angra
# City not found. Skipping...
# Processing Record 407 of Set 8 | santa rosa
# Processing Record 409 of Set 9 | naifaru
# Processing Record 410 of Set 9 | muisne
# Processing Record 411 of Set 9 | tilichiki
# Processing Record 412 of Set 9 | ust-kuyga
# Processing Record 413 of Set 9 | alto araguaia
# Processing Record 414 of Set 9 | roma
# Processing Record 415 of Set 9 | dhidhdhoo
# Processing Record 416 of Set 9 | dali
# Processing Record 417 of Set 9 | kloulklubed
# Processing Record 418 of Set 9 | longyearbyen
# Processing Record 419 of Set 9 | nosy varika
# Processing Record 420 of Set 9 | korla
# Processing Record 421 of Set 9 | nata
# Processing Record 422 of Set 9 | pingzhuang
# Processing Record 423 of Set 9 | vernon
# Processing Record 424 of Set 9 | sebezh
# Processing Record 425 of Set 9 | scottsburgh
# City not found. Skipping...
# Processing Record 426 of Set 9 | dedza
# Processing Record 427 of Set 9 | arcachon
# Processing Record 428 of Set 9 | whitehorse
# Processing Record 429 of Set 9 | touros
# Processing Record 430 of Set 9 | morondava
# Processing Record 431 of Set 9 | chokurdakh
# Processing Record 432 of Set 9 | bonavista
# Processing Record 433 of Set 9 | tosno
# Processing Record 434 of Set 9 | constitucion
# Processing Record 435 of Set 9 | axixa do tocantins
# City not found. Skipping...
# Processing Record 436 of Set 9 | sumbe
# Processing Record 437 of Set 9 | burica
# City not found. Skipping...
# Processing Record 438 of Set 9 | erzin
# Processing Record 439 of Set 9 | magadan
# Processing Record 440 of Set 9 | neuquen
# Processing Record 441 of Set 9 | punta ocote
# Processing Record 442 of Set 9 | ketchikan
# Processing Record 443 of Set 9 | ternate
# Processing Record 444 of Set 9 | acarau
# Processing Record 445 of Set 9 | brae
# Processing Record 446 of Set 9 | karakose
# City not found. Skipping...
# Processing Record 447 of Set 9 | baykit
# Processing Record 448 of Set 9 | medicine hat
# Processing Record 449 of Set 9 | pishin
# Processing Record 450 of Set 9 | cachira
# Processing Record 451 of Set 9 | savonlinna
# Processing Record 452 of Set 9 | nantucket
# Processing Record 453 of Set 9 | lokosovo
# Processing Record 454 of Set 9 | kungurtug
# Processing Record 455 of Set 9 | ixtapa
# Processing Record 456 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 457 of Set 9 | taksimo
# Processing Record 458 of Set 9 | angleton
# Processing Record 460 of Set 10 | kuala pilah
# Processing Record 461 of Set 10 | coahuayana
# Processing Record 462 of Set 10 | nsanje
# Processing Record 463 of Set 10 | pailitas
# Processing Record 464 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 465 of Set 10 | buren
# Processing Record 466 of Set 10 | egvekinot
# Processing Record 467 of Set 10 | melbu
# Processing Record 468 of Set 10 | xuddur
# Processing Record 469 of Set 10 | vao
# Processing Record 470 of Set 10 | iquique
# Processing Record 471 of Set 10 | black forest
# Processing Record 472 of Set 10 | prattville
# Processing Record 473 of Set 10 | leeuwarden
# Processing Record 474 of Set 10 | lodja
# Processing Record 475 of Set 10 | rio grande
# Processing Record 476 of Set 10 | rupert
# Processing Record 477 of Set 10 | cairns
# Processing Record 478 of Set 10 | gat
# Processing Record 479 of Set 10 | bethel
# Processing Record 480 of Set 10 | coihaique
# Processing Record 481 of Set 10 | rapid valley
# Processing Record 482 of Set 10 | qaqortoq
# Processing Record 483 of Set 10 | waingapu
# Processing Record 484 of Set 10 | padang
# Processing Record 485 of Set 10 | vestmannaeyjar
# Processing Record 486 of Set 10 | tura
# Processing Record 487 of Set 10 | almeirim
# Processing Record 488 of Set 10 | tateyama
# Processing Record 489 of Set 10 | bulungu
# Processing Record 490 of Set 10 | turukhansk
# Processing Record 491 of Set 10 | pantai remis
# Processing Record 492 of Set 10 | green river
# Processing Record 493 of Set 10 | yankton
# Processing Record 494 of Set 10 | nizhniy kuranakh
# Processing Record 495 of Set 10 | aksu
# Processing Record 496 of Set 10 | saint-junien
# Processing Record 497 of Set 10 | nizhnevartovsk
# Processing Record 498 of Set 10 | ulladulla
# Processing Record 499 of Set 10 | carnarvon
# Processing Record 500 of Set 10 | milkovo
# Processing Record 501 of Set 10 | mayya
# Processing Record 502 of Set 10 | isangel
# Processing Record 503 of Set 10 | madras
# Processing Record 504 of Set 10 | la rioja
# Processing Record 505 of Set 10 | ballina
# Processing Record 506 of Set 10 | atambua
# Processing Record 507 of Set 10 | inuvik
# Processing Record 508 of Set 10 | townsville
# Processing Record 509 of Set 10 | ino
# Processing Record 511 of Set 11 | bacuit
# City not found. Skipping...
# Processing Record 512 of Set 11 | mananjary
# Processing Record 513 of Set 11 | birnin kebbi
# Processing Record 514 of Set 11 | teya
# Processing Record 515 of Set 11 | lar
# Processing Record 516 of Set 11 | cayenne
# Processing Record 517 of Set 11 | ishigaki
# Processing Record 518 of Set 11 | san luis
# Processing Record 519 of Set 11 | half moon bay
# Processing Record 520 of Set 11 | laguna
# Processing Record 521 of Set 11 | bose
# Processing Record 522 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 523 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 524 of Set 11 | caravelas
# Processing Record 525 of Set 11 | kwinana
# Processing Record 526 of Set 11 | cadillac
# Processing Record 527 of Set 11 | portland
# Processing Record 528 of Set 11 | bud
# Processing Record 529 of Set 11 | pangnirtung
# Processing Record 530 of Set 11 | kampong chhnang
# Processing Record 531 of Set 11 | donskoye
# Processing Record 532 of Set 11 | necochea
# Processing Record 533 of Set 11 | linden
# Processing Record 534 of Set 11 | haimen
# Processing Record 535 of Set 11 | besikduzu
# Processing Record 536 of Set 11 | wanning
# Processing Record 537 of Set 11 | ust-kulom
# Processing Record 538 of Set 11 | superior
# Processing Record 539 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 540 of Set 11 | hwange
# Processing Record 541 of Set 11 | bodaybo
# Processing Record 542 of Set 11 | konde
# Processing Record 543 of Set 11 | zhanaozen
# Processing Record 544 of Set 11 | sola
# Processing Record 545 of Set 11 | felipe carrillo puerto
# Processing Record 546 of Set 11 | broome
# Processing Record 547 of Set 11 | marsa matruh
# Processing Record 548 of Set 11 | berbera
# Processing Record 549 of Set 11 | maceio
# Processing Record 550 of Set 11 | tukrah
# Processing Record 551 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 552 of Set 11 | shebalino
# Processing Record 553 of Set 11 | ulaanbaatar
# Processing Record 554 of Set 11 | koshurnikovo
# Processing Record 555 of Set 11 | ayagoz
# Processing Record 556 of Set 11 | evensk
# Processing Record 557 of Set 11 | san andres
# Processing Record 558 of Set 11 | choszczno
# Processing Record 559 of Set 11 | san miguel
# Processing Record 560 of Set 11 | malatya
# Processing Record 562 of Set 12 | parainen
# Processing Record 563 of Set 12 | tingi
# Processing Record 564 of Set 12 | koslan
# Processing Record 565 of Set 12 | vila franca do campo
# Processing Record 566 of Set 12 | shimoda
# Processing Record 567 of Set 12 | rawlins
# Processing Record 568 of Set 12 | haifa
# Processing Record 569 of Set 12 | galgani
# City not found. Skipping...
# Processing Record 570 of Set 12 | kirakira
# Processing Record 571 of Set 12 | durango
# Processing Record 572 of Set 12 | poso
# Processing Record 573 of Set 12 | kidal
# Processing Record 574 of Set 12 | tongliao
# Processing Record 575 of Set 12 | kaspiyskiy
# Processing Record 576 of Set 12 | amga
# Processing Record 577 of Set 12 | beringovskiy
# Processing Record 578 of Set 12 | bahia blanca
# Processing Record 579 of Set 12 | skorodnoye
# Processing Record 580 of Set 12 | phuket
# Processing Record 581 of Set 12 | sartell
# Processing Record 582 of Set 12 | iqaluit
# Processing Record 583 of Set 12 | sainte-suzanne
# Processing Record 584 of Set 12 | changli
# Processing Record 585 of Set 12 | natal
# Processing Record 586 of Set 12 | kedrovyy
# Processing Record 587 of Set 12 | huadian
# Processing Record 588 of Set 12 | embonas
# Processing Record 589 of Set 12 | mount gambier
# Processing Record 590 of Set 12 | rio gallegos
# Processing Record 591 of Set 12 | mishan
# Processing Record 592 of Set 12 | mandera
# Processing Record 593 of Set 12 | port-gentil
# Processing Record 594 of Set 12 | vuktyl
# Processing Record 595 of Set 12 | puerto quijarro
# Processing Record 596 of Set 12 | tongren
# Processing Record 597 of Set 12 | gazojak
# Processing Record 598 of Set 12 | botad
# Processing Record 599 of Set 12 | ingham
# Processing Record 600 of Set 12 | buariki
# City not found. Skipping...
# Processing Record 601 of Set 12 | vardo
# Processing Record 602 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 603 of Set 12 | sa kaeo
# Processing Record 604 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 605 of Set 12 | grong
# Processing Record 606 of Set 12 | srednekolymsk
# Processing Record 607 of Set 12 | campbell river
# Processing Record 608 of Set 12 | buloh kasap
# Processing Record 609 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 610 of Set 12 | udachnyy
# Processing Record 611 of Set 12 | los chiles
# Processing Record 613 of Set 13 | sheffield
# Processing Record 614 of Set 13 | yerbogachen
# Processing Record 615 of Set 13 | sahuaripa
# Processing Record 616 of Set 13 | arti
# Processing Record 617 of Set 13 | wajima
# Processing Record 618 of Set 13 | afmadu
# City not found. Skipping...
# Processing Record 619 of Set 13 | almaznyy
# Processing Record 620 of Set 13 | muroto
# Processing Record 621 of Set 13 | itupiranga
# Processing Record 622 of Set 13 | springfield
# Processing Record 623 of Set 13 | rudnyy
# Processing Record 624 of Set 13 | robertsport
# Processing Record 625 of Set 13 | puerto del rosario
# Processing Record 626 of Set 13 | hammerfest
# Processing Record 627 of Set 13 | eyl
# Processing Record 628 of Set 13 | grindavik
# Processing Record 629 of Set 13 | dakar
# Processing Record 630 of Set 13 | marihatag
# Processing Record 631 of Set 13 | yushala
# Processing Record 632 of Set 13 | omboue
# Processing Record 633 of Set 13 | waverly
# Processing Record 634 of Set 13 | ahipara
# Processing Record 635 of Set 13 | panguna
# Processing Record 636 of Set 13 | devonport
# Processing Record 637 of Set 13 | falun
# Processing Record 638 of Set 13 | tapaua
# City not found. Skipping...
# Processing Record 639 of Set 13 | berlevag
# Processing Record 640 of Set 13 | iglesias
# Processing Record 641 of Set 13 | ijaki
# City not found. Skipping...
# Processing Record 642 of Set 13 | artesia
# Processing Record 643 of Set 13 | raudeberg
# Processing Record 644 of Set 13 | iraray
# Processing Record 645 of Set 13 | usakos
# Processing Record 646 of Set 13 | poya
# Processing Record 647 of Set 13 | general roca
# Processing Record 648 of Set 13 | williston
# Processing Record 649 of Set 13 | kudahuvadhoo
# Processing Record 650 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 651 of Set 13 | shively
# Processing Record 652 of Set 13 | peniche
# Processing Record 653 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 654 of Set 13 | biak
# Processing Record 655 of Set 13 | ust-omchug
# Processing Record 656 of Set 13 | port blair
# Processing Record 657 of Set 13 | bereda
# Processing Record 658 of Set 13 | paytug
# City not found. Skipping...
# Processing Record 659 of Set 13 | venustiano carranza
# Processing Record 660 of Set 13 | puerto penasco
# Processing Record 661 of Set 13 | sutysky
# Processing Record 662 of Set 13 | zaysan
# Processing Record 664 of Set 14 | puerto montt
# Processing Record 665 of Set 14 | keshorai patan
# Processing Record 666 of Set 14 | tete
# Processing Record 667 of Set 14 | lapa
# Processing Record 668 of Set 14 | manavalakurichi
# Processing Record 669 of Set 14 | college
# Processing Record 670 of Set 14 | nabire
# Processing Record 671 of Set 14 | abong mbang
# Processing Record 672 of Set 14 | corcoran
# Processing Record 673 of Set 14 | pinerolo
# Processing Record 674 of Set 14 | panacan
# Processing Record 675 of Set 14 | ukiah
# Processing Record 676 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 677 of Set 14 | charleston
# Processing Record 678 of Set 14 | jumla
# Processing Record 679 of Set 14 | marienburg
# Processing Record 680 of Set 14 | birao
# Processing Record 681 of Set 14 | rongcheng
# Processing Record 682 of Set 14 | uvarovka
# Processing Record 683 of Set 14 | midland
# Processing Record 684 of Set 14 | trinidad
# Processing Record 685 of Set 14 | alofi
# Processing Record 686 of Set 14 | sao sebastiao
# Processing Record 687 of Set 14 | sawtell
# Processing Record 688 of Set 14 | kuching
# Processing Record 689 of Set 14 | bury saint edmunds
# City not found. Skipping...
# Processing Record 690 of Set 14 | port victoria
# Processing Record 691 of Set 14 | haines junction
# Processing Record 692 of Set 14 | whitecourt
# Processing Record 693 of Set 14 | catalina
# Processing Record 694 of Set 14 | mogadishu
# Processing Record 695 of Set 14 | morden
# Processing Record 696 of Set 14 | brekstad
# Processing Record 697 of Set 14 | bonoua
# Processing Record 698 of Set 14 | bima
# Processing Record 699 of Set 14 | liverpool
# Processing Record 700 of Set 14 | topchikha
# Processing Record 701 of Set 14 | lakes entrance
# Processing Record 702 of Set 14 | newport
# Processing Record 703 of Set 14 | narimanov
# Processing Record 704 of Set 14 | havre-saint-pierre
# Processing Record 705 of Set 14 | yar-sale
# Processing Record 706 of Set 14 | esqueda
# Processing Record 707 of Set 14 | mokhsogollokh
# Processing Record 708 of Set 14 | hamilton
# Processing Record 709 of Set 14 | vershino-darasunskiy
# Processing Record 710 of Set 14 | petukhovo
# Processing Record 711 of Set 14 | nexo
# Processing Record 712 of Set 14 | ouesso
# Processing Record 713 of Set 14 | okhotsk
# Processing Record 715 of Set 15 | fairfield
# Processing Record 716 of Set 15 | alindao
# Processing Record 717 of Set 15 | riviere-au-renard
# Processing Record 718 of Set 15 | saint-georges
# Processing Record 719 of Set 15 | kegayli
# City not found. Skipping...
# Processing Record 720 of Set 15 | ambilobe
# Processing Record 721 of Set 15 | saurimo
# Processing Record 722 of Set 15 | vanavara
# Processing Record 723 of Set 15 | barmer
# Processing Record 724 of Set 15 | guanica
# Processing Record 725 of Set 15 | hobyo
# Processing Record 726 of Set 15 | worpswede
# Processing Record 727 of Set 15 | susanville
# Processing Record 728 of Set 15 | karratha
# Processing Record 729 of Set 15 | ostrovnoy
# Processing Record 730 of Set 15 | sault sainte marie
# Processing Record 731 of Set 15 | cabedelo
# Processing Record 732 of Set 15 | canmore
# Processing Record 733 of Set 15 | kuytun
# Processing Record 734 of Set 15 | puerto colombia
# Processing Record 735 of Set 15 | piacabucu
# Processing Record 736 of Set 15 | ajdabiya
# Processing Record 737 of Set 15 | walvis bay
# Processing Record 738 of Set 15 | nador
# Processing Record 739 of Set 15 | mirnyy
# Processing Record 740 of Set 15 | lancut
# Processing Record 741 of Set 15 | eyrarbakki
# Processing Record 742 of Set 15 | ikornnes
# Processing Record 743 of Set 15 | awjilah
# Processing Record 744 of Set 15 | littleton
# Processing Record 745 of Set 15 | vermilion
# Processing Record 746 of Set 15 | frontera
# Processing Record 747 of Set 15 | eucaliptus
# Processing Record 748 of Set 15 | montanha
# Processing Record 749 of Set 15 | guilin
# Processing Record 750 of Set 15 | palmer
# Processing Record 751 of Set 15 | we
# City not found. Skipping...
# Processing Record 752 of Set 15 | syracuse
# Processing Record 753 of Set 15 | potamia
# Processing Record 754 of Set 15 | manggar
# Processing Record 755 of Set 15 | daokou
# Processing Record 756 of Set 15 | oum hadjer
# Processing Record 757 of Set 15 | arlit
# Processing Record 758 of Set 15 | pueblo
# Processing Record 759 of Set 15 | drayton valley
# Processing Record 760 of Set 15 | chingirlau
# Processing Record 761 of Set 15 | paamiut
# Processing Record 762 of Set 15 | maracas
# Processing Record 763 of Set 15 | nishihara
# Processing Record 764 of Set 15 | vangaindrano
# Processing Record 766 of Set 16 | batagay
# Processing Record 767 of Set 16 | longlac
# City not found. Skipping...
# Processing Record 768 of Set 16 | mehamn
# Processing Record 769 of Set 16 | itiuba
# Processing Record 770 of Set 16 | vallenar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 692

# %%
# Convert the array of dictionaries in a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Rikitea      PF -23.1203 -134.9692     74.10        80          94
# 1  Port Elizabeth      ZA -33.9180   25.5701     52.09        87           0
# 2    Komsomolskiy      UZ  40.4272   71.7189     79.52        38           0
# 3        Bathurst      AU -33.4166  149.5806     56.82        68          87
# 4            Lebu      CL -37.6167  -73.6500     50.99        89          99
# 5           Roald      NO  62.5833    6.1333     55.76        82         100
# 6          Riyadh      SA  24.6877   46.7219     93.34        10          33
# 7      Codrington      AU -38.2667  141.9667     52.11        77          86
# 8          Sangar      RU  63.9242  127.4739     63.86        94          90
# 9     New Norfolk      AU -42.7826  147.0587     47.91        80           2
#
#    Wind Speed Current Description
# 0       23.02          light rain
# 1        6.91           clear sky
# 2        9.22           clear sky
# 3        1.99     overcast clouds
# 4       11.03       moderate rain
# 5        3.44     overcast clouds
# 6        9.86    scattered clouds
# 7       13.15     overcast clouds
# 8        3.33     overcast clouds
# 9        3.24           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
